# %% [markdown]
# ## Introduction:
# ##### This dataset is called Accidental Drug Related Deaths 2012-2023, from the Conneticut state government. It's a listing of each accidental death associated with drug overdose in Connecticut from 2012 to 2023.
# ##### Dataset link: https://data.ct.gov/Health-and-Human-Services/Accidental-Drug-Related-Deaths-2012-2023/rybz-nyjw/about_data

# %%
# Import important libraries for data analysis and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = pd.read_csv('/Users/holly/Desktop/PUBH 1242/Accidental_Drug_Related_Deaths_2012-2023_20241208.csv')
# Display the first 5 rows of the data
data.head()
# Out:
#          Date      Date Type   Age     Sex   Race Ethnicity Residence City  \
# 0  05/29/2012  Date of death  37.0    Male  Black       NaN       STAMFORD
# 1  06/27/2012  Date of death  37.0    Male  White       NaN        NORWICH
# 2  03/24/2014  Date of death  28.0    Male  White       NaN         HEBRON
# 3  12/31/2014  Date of death  26.0  Female  White       NaN         BALTIC
# 4  01/16/2016  Date of death  41.0    Male  White       NaN        SHELTON
#
#   Residence County Residence State Injury City  ... Xylazine Gabapentin  \
# 0        FAIRFIELD             NaN    STAMFORD  ...      NaN        NaN
# 1       NEW LONDON             NaN     NORWICH  ...      NaN        NaN
# 2              NaN             NaN      HEBRON  ...      NaN        NaN
# 3              NaN             NaN         NaN  ...      NaN        NaN
# 4        FAIRFIELD              CT     SHELTON  ...      NaN        NaN
#
#   Opiate NOS Heroin/Morph/Codeine Other Opioid Any Opioid Other  \
# 0        NaN                  NaN          NaN        NaN   NaN
# 1        NaN                  NaN          NaN        NaN   NaN
# 2        NaN                  NaN          NaN        NaN   NaN
# 3        NaN                  NaN          NaN        NaN   NaN
# 4        NaN                  NaN          NaN          Y   NaN
#
#                         ResidenceCityGeo  \
# 0  STAMFORD, CT\n(41.051924, -73.539475)
# 1   NORWICH, CT\n(41.524304, -72.075821)
# 2    HEBRON, CT\n(41.658069, -72.366324)
# 3    BALTIC, CT\n(41.617221, -72.085031)
# 4   SHELTON, CT\n(41.316843, -73.092968)
#
#                            InjuryCityGeo  \
# 0  STAMFORD, CT\n(41.051924, -73.539475)
# 1   NORWICH, CT\n(41.524304, -72.075821)
# 2    HEBRON, CT\n(41.658069, -72.366324)
# 3            CT\n(41.575155, -72.738288)
# 4   SHELTON, CT\n(41.316843, -73.092968)
#
#                                DeathCityGeo
# 0               CT\n(41.575155, -72.738288)
# 1      Norwich, CT\n(41.524304, -72.075821)
# 2  Marlborough, CT\n(41.632043, -72.461309)
# 3       Baltic, CT\n(41.617221, -72.085031)
# 4   Bridgeport, CT\n(41.179195, -73.189476)
#
# [5 rows x 48 columns]

# %%
# Display the variable names
data.columns
# Out:
# Index(['Date', 'Date Type', 'Age', 'Sex', 'Race', 'Ethnicity',
#        'Residence City', 'Residence County', 'Residence State', 'Injury City',
#        'Injury County', 'Injury State', 'Injury Place',
#        'Description of Injury', 'Death City', 'Death County', 'Death State',
#        'Location', 'Location if Other', 'Cause of Death', 'Manner of Death',
#        'Other Significant Conditions ', 'Heroin',
#        'Heroin death certificate (DC)', 'Cocaine', 'Fentanyl',
#        'Fentanyl Analogue', 'Oxycodone', 'Oxymorphone', 'Ethanol',
#        'Hydrocodone', 'Benzodiazepine', 'Methadone', 'Meth/Amphetamine',
#        'Amphet', 'Tramad', 'Hydromorphone', 'Morphine (Not Heroin)',
#        'Xylazine', 'Gabapentin', 'Opiate NOS', 'Heroin/Morph/Codeine',
#        'Other Opioid', 'Any Opioid', 'Other', 'ResidenceCityGeo',
#        'InjuryCityGeo', 'DeathCityGeo'],
#       dtype='object')

# %%
# how many deaths are there in the data?
data.shape[0]
# Out:
# 11981

# %% [markdown]
# ## Exploring the Data

# %%
# Plot the trends in drug use over time
plt.figure(figsize=(12,6))

drug_trends.plot(kind='line', marker='o', ax=plt.gca())

# Set the title and labels
plt.title('Trends in Drug Use Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.legend(title='Drug')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 # Plot the trends in drug use over time
#       2 plt.figure(figsize=(12,6))
# ----> 4 drug_trends.plot(kind='line', marker='o', ax=plt.gca())
#       6 # Set the title and labels
#       7 plt.title('Trends in Drug Use Over Time')
#
# NameError: name 'drug_trends' is not defined

# %% [markdown]
# #### This plot shows that heroin related deaths have always been common. Oxycodone peaks significantly in 2015, ad falls off right after that. Fentanyl peaks in 2016

# %% [markdown]
# ### Now let's look at the death distribution per city

# %%
# figure out which city has the most drug related deaths
city_deaths = data['Death City'].value_counts().head(10)
plt.figure(figsize=(12,6))
sns.barplot(x=city_deaths.values, y=city_deaths.index, palette='magma')
plt.title('Top 10 Cities with the Most Drug-Related Deaths')
plt.xlabel('Number of Deaths')
plt.ylabel('City')
plt.show()
# Out:
# /var/folders/fd/tf9m44dj0tvfhkp_rp0b4p040000gn/T/ipykernel_41047/280412669.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_deaths.values, y=city_deaths.index, palette='magma')

# %% [markdown]
# #### Hartford, New Haven and Waterbury have the highest number of deaths, whcih isn't surprising considering the fact that they have some of the highest population in connecticut

# %%
# Analyze the distribution of deaths by age
plt.figure(figsize=(12,6))
sns.histplot(data['Age'], bins=30, kde=True, color='purple')
plt.title('Distribution of Deaths by Age')
plt.xlabel('Age')
plt.ylabel('Number of Deaths')
plt.show()

# %% [markdown]
# ### As for age distribution, the range seems to be from 15 years old to 80 years old

# %%
import matplotlib.pyplot as plt

# Group the data by race and count the number of deaths
race_deaths = data['Race'].value_counts()

# Make the plot
plt.figure(figsize=(10, 6))
race_deaths.plot(kind='bar', color='orange')
plt.title('Distribution of Deaths by Race')
plt.xlabel('Race')
plt.ylabel('Number of Deaths')
plt.show()

# %%
# look at the distribution of the sex column

gender_deaths = data['Sex'].value_counts()

# Make the plot
plt.figure(figsize=(10, 6))
gender_deaths.plot(kind='bar')
plt.title('Distribution of Deaths by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Deaths')
plt.show()

# %%
data[['Location']].value_counts()
# Out:
# Location
# Residence                     4799
# Hospital                      2336
# Other                         1559
# Decedent’s Home                776
# Hospital - ER/Outpatient       401
# Other (Specify)                362
# Hospital - Inpatient           246
# Hospital - Dead On Arrival      81
# Decedent's Home                 52
# Nursing Home                     9
# Convalescent Home                3
# Hospice                          3
# Assisted Living                  2
# Hiospital                        1
# Hospice Facility                 1
# Shelter                          1
# Name: count, dtype: int64

# %%
# show column names
data.columns
# Out:
# Index(['Date', 'Date Type', 'Age', 'Sex', 'Race', 'Ethnicity',
#        'Residence City', 'Residence County', 'Residence State', 'Injury City',
#        'Injury County', 'Injury State', 'Injury Place',
#        'Description of Injury', 'Death City', 'Death County', 'Death State',
#        'Location', 'Location if Other', 'Cause of Death', 'Manner of Death',
#        'Other Significant Conditions ', 'Heroin',
#        'Heroin death certificate (DC)', 'Cocaine', 'Fentanyl',
#        'Fentanyl Analogue', 'Oxycodone', 'Oxymorphone', 'Ethanol',
#        'Hydrocodone', 'Benzodiazepine', 'Methadone', 'Meth/Amphetamine',
#        'Amphet', 'Tramad', 'Hydromorphone', 'Morphine (Not Heroin)',
#        'Xylazine', 'Gabapentin', 'Opiate NOS', 'Heroin/Morph/Codeine',
#        'Other Opioid', 'Any Opioid', 'Other', 'ResidenceCityGeo',
#        'InjuryCityGeo', 'DeathCityGeo'],
#       dtype='object')

# %%
# look at the DescriptionofInjury column
data['Description of Injury'].value_counts()
# Out:
# Description of Injury
# Substance Abuse                                    3233
# Drug Use                                           1298
# Substance abuse                                    1212
# Substance use                                      1039
# Substance Use                                       997
#                                                    ...
# Used ethanol and methadone                            1
# Took illicit drug with prescribed medications         1
# Injection/Ingestion                                   1
# Drank Alcohol and Took Prescription Medications       1
# Used Cocaine and Ethanol                              1
# Name: count, Length: 539, dtype: int64

# %%
# combine all the data that says "substance abuse" and 'drug abuse' into one category
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Substance Abuse' if isinstance(x, str) and 'substance abuse' in x.lower() else x)

# do the same thing with 'drug use'
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Drug Use' if isinstance(x, str) and 'drug use' in x.lower() else x)

# do the same thing with 'Substance use', 'substance use', 'Substance Use'
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Substance Use' if isinstance(x, str) and 'substance use' in x.lower() else x)

# do the same thing with 'Substance Abuse', 'Substance abuse'
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Substance Abuse' if isinstance(x, str) and 'substance abuse' in x.lower() else x)

# %%
# combine all the data that says "drug use and drug abuse" into one category
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Drug Use and Drug Abuse' if isinstance(x, str) and 'drug use and drug abuse' in x.lower() else x)
# do the same thing with 'substance use and substance abuse'
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Substance Use and Substance Abuse' if isinstance(x, str) and 'substance use and substance abuse' in x.lower() else x)

# %%
# Display the updated counts
data['DescriptionofInjury'].value_counts()
# Out:
# DescriptionofInjury
# Substance Abuse                                    3233
# Drug Use                                           1298
# Substance abuse                                    1212
# Substance use                                      1039
# Substance Use                                       997
#                                                    ...
# Used ethanol and methadone                            1
# Took illicit drug with prescribed medications         1
# Injection/Ingestion                                   1
# Drank Alcohol and Took Prescription Medications       1
# Used Cocaine and Ethanol                              1
# Name: count, Length: 539, dtype: int64

# %%
# combine all the subtance use and drug use into one category and do the same thing with substance abuse and drug abuse
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Substance Use' if isinstance(x, str) and 'substance use' in x.lower() else x)
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Drug Use' if isinstance(x, str) and 'drug use' in x.lower() else x)
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Substance Abuse' if isinstance(x, str) and 'substance abuse' in x.lower() else x)
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Drug Abuse' if isinstance(x, str) and 'drug abuse' in x.lower() else x)

# Display the updated counts
data['DescriptionofInjury'].value_counts()
# Out:
# DescriptionofInjury
# Substance Abuse                                    3233
# Drug Use                                           1298
# Substance abuse                                    1212
# Substance use                                      1039
# Substance Use                                       997
#                                                    ...
# Took illicit drug with prescribed medications         1
# Injection/Ingestion                                   1
# Drank Alcohol and Took Prescription Medications       1
# Consumed ethanol and buprenorphine                    1
# Used Cocaine and Ethanol                              1
# Name: count, Length: 533, dtype: int64

# %%
# use SVM to combine all the data that says "substance abuse" and 'drug abuse' into one category
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Substance Abuse' if isinstance(x, str) and 'substance abuse' in x.lower() else x)

# do the same thing with 'drug use'
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Drug Use' if isinstance(x, str) and 'drug use' in x.lower() else x)

# do the same thing with 'Substance use', 'substance use', 'Substance Use'
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Substance Use' if isinstance(x, str) and 'substance use' in x.lower() else x)

# do the same thing with 'Substance Abuse', 'Substance abuse'
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Substance Abuse' if isinstance(x, str) and 'substance abuse' in x.lower() else x)

# combine all the data that says "drug use and drug abuse" into one category
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Drug Use and Drug Abuse' if isinstance(x, str) and 'drug use and drug abuse' in x.lower() else x)
# do the same thing with 'substance use and substance abuse'
data['DescriptionofInjury'] = data['Description of Injury'].apply(lambda x: 'Substance Use and Substance Abuse' if isinstance(x, str) and 'substance use and substance abuse' in x.lower() else x)

# Display the updated counts
data['DescriptionofInjury'].value_counts()
# Out:
# DescriptionofInjury
# Substance Abuse                                    3233
# Drug Use                                           1298
# Substance abuse                                    1212
# Substance use                                      1039
# Substance Use                                       997
#                                                    ...
# Used ethanol and methadone                            1
# Took illicit drug with prescribed medications         1
# Injection/Ingestion                                   1
# Drank Alcohol and Took Prescription Medications       1
# Used Cocaine and Ethanol                              1
# Name: count, Length: 539, dtype: int64

# %%
# float or string data type?
data['Description of Injury'].dtype
# Out:
# dtype('O')

# %%
import nltk

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/holly/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/holly/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# visualize the distribution of injury descriptions but only include the top 5
plt.figure(figsize=(10,6))
sns.barplot(x=injury_description.index, y=injury_description.values, palette='viridis')
plt.title('Distribution of Injury Descriptions')
plt.xlabel('Description')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # visualize the distribution of injury descriptions but only include the top 5
#       2 plt.figure(figsize=(10,6))
# ----> 3 sns.barplot(x=injury_description.index, y=injury_description.values, palette='viridis')
#       4 plt.title('Distribution of Injury Descriptions')
#       5 plt.xlabel('Description')
#
# NameError: name 'injury_description' is not defined

# %% [markdown]
# 1. **Split the data**: Split your dataset into training and testing sets.
# 2. **Train the model**: Train your machine learning model on the training set.
# 3. **Make predictions**: Use the trained model to make predictions on the testing set.
# 4. **Evaluate the model**: Use various evaluation metrics to assess the model's performance.
#
# Common evaluation metrics for classification problems include:
#
# - **Accuracy**: The proportion of correctly classified instances.
# - **Precision**: The proportion of true positive predictions among all positive predictions.
# - **Recall (Sensitivity)**: The proportion of true positive predictions among all actual positives.
# - **F1 Score**: The harmonic mean of precision and recall.
# - **Confusion Matrix**: A table showing the true positives, false positives, true negatives, and false negatives.

# %%
# look at the location of the deaths
data['Location'].value_counts()
# Out:
# Location
# Residence                     4799
# Hospital                      2336
# Other                         1559
# Decedent’s Home                776
# Hospital - ER/Outpatient       401
# Other (Specify)                362
# Hospital - Inpatient           246
# Hospital - Dead On Arrival      81
# Decedent's Home                 52
# Nursing Home                     9
# Convalescent Home                3
# Hospice                          3
# Assisted Living                  2
# Shelter                          1
# Hiospital                        1
# Hospice Facility                 1
# Name: count, dtype: int64

# %%
# make a graoh looking at the the top 5 locations of deaths
location_deaths = data['Location'].value_counts().head(5)
plt.figure(figsize=(10,6))
sns.barplot(x=location_deaths.index, y=location_deaths.values, palette='viridis')
plt.title('Top 5 Locations of Deaths')
plt.xlabel('Location')
plt.ylabel('Number of Deaths')
plt.show()
# Out:
# /var/folders/fd/tf9m44dj0tvfhkp_rp0b4p040000gn/T/ipykernel_41047/1358795233.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=location_deaths.index, y=location_deaths.values, palette='viridis')

# %%
# look at the location other 
data['Location if Other'].value_counts()
# Out:
# Location if Other
# Friend's Residence     68
# Hotel                  42
# Friend's House         41
# Friend's Home          36
# In Vehicle             28
#                        ..
# Girlfriend's apt.       1
# Uncle's House           1
# Abandoned Garage        1
# Temporary Residence     1
# Parked vehicle          1
# Name: count, Length: 543, dtype: int64

# %%
# plot the other locations
other_location_deaths = data['Location if Other'].value_counts().head(10)
plt.figure(figsize=(12,6))
sns.barplot(x=other_location_deaths.values, y=other_location_deaths.index, palette='magma')
plt.title('Top 10 Other Locations with the Most Drug-Related Deaths')
plt.xlabel('Number of Deaths')
plt.ylabel('Location')
plt.show()
# Out:
# /var/folders/fd/tf9m44dj0tvfhkp_rp0b4p040000gn/T/ipykernel_55166/1645836765.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=other_location_deaths.values, y=other_location_deaths.index, palette='magma')

# %%
# Combine all the data that says "Friend's" into one category from the Location if Other column and plot the top 10 locations
data['Location if Other'] = data['Location if Other'].apply(lambda x: "Friend's House" if isinstance(x, str) and "friend's" in x.lower() else x)
other_location_deaths = data['Location if Other'].value_counts().head(10)
plt.figure(figsize=(12,6))
sns.barplot(x=other_location_deaths.values, y=other_location_deaths.index, palette='magma')
plt.title('Top 10 Other Locations with the Most Drug-Related Deaths')
plt.xlabel('Number of Deaths')
plt.ylabel('Location')
plt.show()
# Out:
# /var/folders/fd/tf9m44dj0tvfhkp_rp0b4p040000gn/T/ipykernel_55166/2284840305.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=other_location_deaths.values, y=other_location_deaths.index, palette='magma')

# %% [markdown]
# ## Cluster geographic locations of deaths to identify hotspots using KMeans

# %% [markdown]
# #### 1. Extract latitude and longitude as numeric columns from DeathCityGeo.

# %%
from sklearn.cluster import KMeans

# make a geo_data dataframe
geo_data = data[['DeathCityGeo']].dropna()

# look at how the death city geo data is structured

geo_data['DeathCityGeo'].head()

# split the data into latitude and longitude
geo_data['Latitude'] = geo_data['DeathCityGeo'].apply(lambda x: x.split(',')[0])
geo_data['Longitude'] = geo_data['DeathCityGeo'].apply(lambda x: x.split(',')[1])

# %%
import pandas as pd
from sklearn.cluster import KMeans
import folium
import numpy as np

# Ensure DeathCityGeo data is available
geo_data = data[['DeathCityGeo']].dropna()

# Extract latitude and longitude
geo_data['Latitude'] = geo_data['DeathCityGeo'].apply(lambda x: float(x.split('(')[-1].split(',')[0]))
geo_data['Longitude'] = geo_data['DeathCityGeo'].apply(lambda x: float(x.split(',')[-1].split(')')[0]))

# Display the first few rows to confirm
print(geo_data.head())
# Out:
#                                DeathCityGeo   Latitude  Longitude
# 0               CT\n(41.575155, -72.738288)  41.575155 -72.738288
# 1      Norwich, CT\n(41.524304, -72.075821)  41.524304 -72.075821
# 2  Marlborough, CT\n(41.632043, -72.461309)  41.632043 -72.461309
# 3       Baltic, CT\n(41.617221, -72.085031)  41.617221 -72.085031
# 4   Bridgeport, CT\n(41.179195, -73.189476)  41.179195 -73.189476

# %% [markdown]
# #### 2. Cluster the Data Use KMeans to find clusters (hotspots) based on the latitude and longitude coordinates.

# %% [markdown]
# Each geographic location is assigned to a cluster based on its proximity to cluster centers.
# kmeans.cluster_centers_ provides the central coordinates of each cluster (hotspots).
# Interactive Map:
#
# Points are plotted with folium, color-coded by cluster.
# Cluster centers are marked to show the central hotspots.

# %%
# Number of clusters (hotspots) - you can adjust this
n_clusters = 9

# Run KMeans on latitude and longitude
kmeans = KMeans(n_clusters=n_clusters, random_state=30)
geo_data['Cluster'] = kmeans.fit_predict(geo_data[['Latitude', 'Longitude']])

# Add cluster centers to analyze
centers = kmeans.cluster_centers_
print("Cluster Centers (Lat, Lon):", centers)
# Out:
# Cluster Centers (Lat, Lon): [[ 41.62749405 -73.04476154]
#  [ 41.57356563 -72.74180871]
#  [ 41.53055067 -72.07181036]
#  [ 41.21586959 -73.15240576]
#  [ 41.78140564 -72.43866023]
#  [ 41.78689472 -72.6729817 ]
#  [ 41.31080413 -72.91182564]
#  [ 41.45341918 -73.43486225]
#  [ 41.08127789 -73.49566094]]

# %% [markdown]
# #### 3. Visualization on a map

# %%
# Initialize a Folium map centered at the mean of the latitudes and longitudes
map_center = [geo_data['Latitude'].mean(), geo_data['Longitude'].mean()]
map_clusters = folium.Map(location=map_center, zoom_start=8)

# Add points for each location and color them based on their cluster
colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'pink', 'yellow']
for i, row in geo_data.iterrows():
    folium.CircleMarker(
        location=(row['Latitude'], row['Longitude']),
        radius=5,
        color=colors[row['Cluster'] % len(colors)],
        fill=True,
        fill_opacity=0.5
    ).add_to(map_clusters)

# Add cluster centers as larger markers
for center in centers:
    folium.Marker(
        location=center,
        popup=f"Cluster Center: {center}",
        icon=folium.Icon(color="black", icon="info-sign")
    ).add_to(map_clusters)

# Save or display the map
map_clusters.save('geo_clusters_map.html')
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3ee540c8729dcc676f645dfbcce9724 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3ee540c8729dcc676f645dfbcce9724&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3ee540c8729dcc676f645dfbcce9724 = L.map(
#                 &quot;map_e3ee540c8729dcc676f645dfbcce9724&quot;,
#                 {
#                     center: [41.53756166382889, -72.79301960411786],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11785968f02aa4193480ecf76267edee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_11785968f02aa4193480ecf76267edee.addTo(map_e3ee540c8729dcc676f645dfbcce9724);
#
#
#             var circle_marker_dc1faf361692939f5ab51061d3afd08a = L.circleMarker(
#                 [41.575155, -72.738288],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3ee540c8729dcc676f645dfbcce9724);
#
#
#             var circle_marker_4e7a3f194993c881bb796b483d8495ae = L.circleMarker(
#                 [41.524304, -72.075821],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3ee540c8729dcc676f645dfbcce9724);
#
#
#             var circle_marker_d4a191e5b562b0f11f626f811c163a50 = L.circleMarker(
#                 [41.632043, -72.461309],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3ee540c8729dcc676f645dfbcce9724);
#
#
#             var circle_marker_fe8763f6832196985ff1357aa96f924d = L.circleMarker(
#                 [41.617221, -72.085031],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3ee540c8729dcc676f645dfbcce9724);
#
#
#             var circle_marker_03994adb9a36f62e474f63194c45b82c = L.circleMarker(
#                 [41.179195, -73.189476],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3ee540c8729dcc676f645dfbcce9724);
#
#
#             var circle_marker_275d4855d3e47189253ac85daaf4e2ef = L.circleMarker(
#                 [41.976501, -72.591985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e3ee540c8729dcc676f645dfbcce9724);
#
#
#             var circle_marker_ebe234486ce52492d7c51c64f546309f = L.circleMarker(
#                 [41.393666, -73.451539],

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

# Determine the optimal number of clusters using the Elbow Method
inertia = []
silhouette = []
range_n_clusters = range(2, 10)  # Test clusters from 2 to 9

for k in range_n_clusters:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(geo_data[['Latitude', 'Longitude']])
    inertia.append(kmeans.inertia_)
    silhouette.append(silhouette_score(geo_data[['Latitude', 'Longitude']], kmeans.labels_))

# Plot the Elbow Curve
plt.figure(figsize=(10, 5))
plt.plot(range_n_clusters, inertia, marker='o')
plt.title('Elbow Method for Optimal Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# Plot Silhouette Scores
plt.figure(figsize=(10, 5))
plt.plot(range_n_clusters, silhouette, marker='o', color='orange')
plt.title('Silhouette Scores for Optimal Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %% [markdown]
# ### More data analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'Date' is the column with date information
data['Date'] = pd.to_datetime(data['Date'])

# Resample data by month
monthly_deaths = data.resample('M', on='Date').size()

# Resample data by year
yearly_deaths = data.resample('Y', on='Date').size()

# Plot yearly deaths
plt.figure(figsize=(12, 6))
plt.plot(yearly_deaths, marker='o', linestyle='-')
plt.title('Yearly Deaths Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Deaths')
plt.grid(True)
plt.show()
# Out:
# /var/folders/fd/tf9m44dj0tvfhkp_rp0b4p040000gn/T/ipykernel_55166/3102081111.py:8: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_deaths = data.resample('M', on='Date').size()
# /var/folders/fd/tf9m44dj0tvfhkp_rp0b4p040000gn/T/ipykernel_55166/3102081111.py:11: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly_deaths = data.resample('Y', on='Date').size()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'Date' is the column with date information
data['Date'] = pd.to_datetime(data['Date'])

# Extract month and year
data['Month'] = data['Date'].dt.month
data['Year'] = data['Date'].dt.year

# Group by month to check for seasonality in deaths
monthly_deaths = data.groupby('Month').size()

# Plot seasonal pattern in deaths
plt.figure(figsize=(12, 6))
plt.plot(monthly_deaths.index, monthly_deaths.values, marker='o', linestyle='-')
plt.title('Seasonal Pattern in Deaths')
plt.xlabel('Month')
plt.ylabel('Number of Deaths')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# Group by month and year to check for seasonality in drug detection
# Assuming 'DrugDetected' is a column indicating drug detection
monthly_drug_detection = data.groupby(['Year', 'Month']).size().unstack(level=0)

# %% [markdown]
# ### Most deaths seem to happen during summer, between may and august
